# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"/home/mt0/22CS60R61/MTP/NipsPaper2023-8E26/MTP_2024/Braindecode/a.csv")

# %%
df.columns
# Out:
# Index(['Subject', 'Model', 'Accuracy'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2232 entries, 0 to 2231
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Subject   2232 non-null   int64
#  1   Model     2232 non-null   object
#  2   Accuracy  2232 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 52.4+ KB

# %%
df['Accuracy'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
# this boxplot is for within subject.
plt.figure(figsize=(20, 10)) 
sns.boxplot(y ='Accuracy',x ='Model', data =df)
plt.show()

# %%
# this boxplot is for cross subject.
import pandas as pd
df2 = pd.read_csv(r"/home/mt0/22CS60R61/MTP/NipsPaper2023-8E26/MTP_2024/Braindecode/ab.csv")

# %%
# this boxplot is for cross subject.
plt.figure(figsize=(20, 10)) 
sns.boxplot(y ='Accuracy',x ='Model', data =df2)
plt.show()

# %%
df3 = pd.read_csv(r"/home/mt0/22CS60R61/MTP/NipsPaper2023-8E26/MTP_2024/Braindecode/av.csv")

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.violinplot(x='Model', y='Accuracy', data=df3, inner=None)
sns.stripplot(x='Model', y='Accuracy', data=df3, jitter=True, color='black', size=4)
plt.title('Violin Plot of Accuracy by Model')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.show()
